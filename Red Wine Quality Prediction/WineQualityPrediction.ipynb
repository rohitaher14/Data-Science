# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import tree

# %%
df=pd.read_csv('winequality_red.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
y=df.quality
X=df.drop('quality',axis=1)

# %%
X_train,X_test, y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1097            8.6             0.520         0.38             1.5      0.096
# 247             8.2             0.600         0.17             2.3      0.072
# 710            10.6             1.025         0.43             2.8      0.080
# 447             9.3             0.480         0.29             2.1      0.127
# 955             8.5             0.210         0.52             1.9      0.090
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1097                  5.0                  18.0  0.99666  3.20       0.52
# 247                  11.0                  73.0  0.99630  3.20       0.45
# 710                  21.0                  84.0  0.99850  3.06       0.57
# 447                   6.0                  16.0  0.99680  3.22       0.72
# 955                   9.0                  23.0  0.99648  3.36       0.67
#
#       alcohol
# 1097      9.4
# 247       9.3
# 710      10.1
# 447      11.2
# 955      10.4

# %%
X_train_scaled=preprocessing.scale(X_train)
X_train_scaled
# Out:
# array([[ 0.1591798 , -0.01995951,  0.5424838 , ..., -0.73826836,
#         -0.80572848, -0.95301939],
#        [-0.0700893 ,  0.43949082, -0.5335499 , ..., -0.73826836,
#         -1.21316632, -1.04578991],
#        [ 1.30552533,  2.88032068,  0.7986823 , ..., -1.64844691,
#         -0.51470145, -0.30362578],
#        ...,
#        [ 0.27381435, -1.28344791,  0.5424838 , ...,  0.49697396,
#          0.35837965,  1.27347298],
#        [-0.35667569,  0.81279421, -1.40462481, ..., -0.28317909,
#          0.41658506, -1.04578991],
#        [ 0.96162167, -0.65170371,  0.9011617 , ..., -0.67325561,
#         -0.9803447 ,  1.27347298]])

# %%
clf=tree.DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
confidence=clf.score(X_test,y_test)
print("\nThe confidence score:\n")
confidence
# Out:
# The confidence score:
# 0.590625

# %%
y_pred=clf.predict(X_test)

# %%
#converting the numpy array to list
x=np.array(y_pred).tolist()

#printing first 5 predictions
print("\nThe prediction:\n")
for i in range(0,5):
    print (x[i])
    
#printing first five expectations
print("\nThe expectation:\n")
print (y_test.head())
# Out:
# The prediction:
#
# 5
# 5
# 6
# 6
# 6
#
# The expectation:
#
# 313    5
# 721    5
# 39     5
# 828    8
# 363    5
# Name: quality, dtype: int64
